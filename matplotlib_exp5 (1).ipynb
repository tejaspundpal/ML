# %%
import matplotlib.pyplot as plt
import numpy as np
years = [2000,2001,2002,2003,2004]
population =  [15544455,44554552,4454125,45464225,11564522]
plt.title("years vs population")
plt.xlabel("years")
plt.ylabel("population")
plt.plot(years,population)
plt.show()

# %%
plt.scatter(years,population)
plt.show()

# %%
import matplotlib.pyplot as plt

data = [189, 185, 195, 149, 189, 147,
		154, 174, 169, 195, 159, 192,
		155, 191, 153, 157, 140, 144,
		172, 157, 181, 182, 166, 167]

plt.hist(data, bins=[140, 150, 160, 175, 185, 200],
		edgecolor="black", color="yellow")

plt.show()

# %%
marks = np.array([100,87,75, 73,93])
#mylabels = ["Maths","Physics", "Chemistry",  "English","Geography"]
myexplode = [0.2,0,0,0,0]
plt.pie(marks,labels =  ["Maths","Physics", "Chemistry",  "English","Geography"],explode = myexplode,shadow = True,autopct = '%1.0f%%')
plt.show()

# %%
plt.plot(years,population,marker = '3')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([2,5,4,9,6,7])
y = np.array([99,94,78,77,85,86])
plt.scatter(x, y)

x = np.array([2,8,7,14,12])
y = np.array([100,112,91,80,85])
plt.scatter(x, y)

plt.show()
